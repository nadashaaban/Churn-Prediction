# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn.csv')
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.head().T
# Out:
#                                  0             1               2  \
# customerID              7590-VHVEG    5575-GNVDE      3668-QPYBK
# gender                      Female          Male            Male
# SeniorCitizen                    0             0               0
# Partner                        Yes            No              No
# Dependents                      No            No              No
# tenure                           1            34               2
# PhoneService                    No           Yes             Yes
# MultipleLines     No phone service            No              No
# InternetService                DSL           DSL             DSL
# OnlineSecurity                  No           Yes             Yes
# OnlineBackup                   Yes            No             Yes
# DeviceProtection                No           Yes              No
# TechSupport                     No            No              No
# ...

# %%
df.describe(include='O').T
# Out:
#                  count unique               top  freq
# customerID        7043   7043        3186-AJIEK     1
# gender            7043      2              Male  3555
# Partner           7043      2                No  3641
# Dependents        7043      2                No  4933
# PhoneService      7043      2               Yes  6361
# MultipleLines     7043      3                No  3390
# InternetService   7043      3       Fiber optic  3096
# OnlineSecurity    7043      3                No  3498
# OnlineBackup      7043      3                No  3088
# DeviceProtection  7043      3                No  3095
# TechSupport       7043      3                No  3473
# StreamingTV       7043      3                No  2810
# StreamingMovies   7043      3                No  2785
# Contract          7043      3    Month-to-month  3875
# PaperlessBilling  7043      2               Yes  4171
# PaymentMethod     7043      4  Electronic check  2365
# ...

# %%
df.drop('customerID', axis=1, inplace=True)

# %%
df.head().T
# Out:
#                                  0             1               2  \
# gender                      Female          Male            Male
# SeniorCitizen                    0             0               0
# Partner                        Yes            No              No
# Dependents                      No            No              No
# tenure                           1            34               2
# PhoneService                    No           Yes             Yes
# MultipleLines     No phone service            No              No
# InternetService                DSL           DSL             DSL
# OnlineSecurity                  No           Yes             Yes
# OnlineBackup                   Yes            No             Yes
# DeviceProtection                No           Yes              No
# TechSupport                     No            No              No
# StreamingTV                     No            No              No
# ...

# %%
len(df[df['TotalCharges'] == ' '])
# Out:
# 11

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

# %%
len(df[df['TotalCharges'] == ' '])
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
df['TotalCharges'].hist()
# Out:
# <Axes: >

# %%
#skewed distribution >> fill with median
df['TotalCharges'] = df['TotalCharges'].fillna(df['TotalCharges'].median())

# %%
df.isnull().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.columns = df.columns.str.lower()

# %%
df.columns
# Out:
# Index(['gender', 'seniorcitizen', 'partner', 'dependents', 'tenure',
#        'phoneservice', 'multiplelines', 'internetservice', 'onlinesecurity',
#        'onlinebackup', 'deviceprotection', 'techsupport', 'streamingtv',
#        'streamingmovies', 'contract', 'paperlessbilling', 'paymentmethod',
#        'monthlycharges', 'totalcharges', 'churn'],
#       dtype='object')

# %%
df['churn'] = (df['churn'] == 'Yes').astype(int)
df['churn']
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 7038    0
# 7039    0
# 7040    0
# 7041    1
# 7042    0
# Name: churn, Length: 7043, dtype: int64

# %%
df.churn.value_counts()
# Out:
# churn
# 0    5174
# 1    1869
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   seniorcitizen     7043 non-null   int64
#  2   partner           7043 non-null   object
#  3   dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   phoneservice      7043 non-null   object
#  6   multiplelines     7043 non-null   object
#  7   internetservice   7043 non-null   object
#  8   onlinesecurity    7043 non-null   object
#  9   onlinebackup      7043 non-null   object
#  10  deviceprotection  7043 non-null   object
#  11  techsupport       7043 non-null   object
#  12  streamingtv       7043 non-null   object
#  13  streamingmovies   7043 non-null   object
#  14  contract          7043 non-null   object
#  15  paperlessbilling  7043 non-null   object
# ...

# %%
df['seniorcitizen'] = df['seniorcitizen'].astype(object)

# %%
categorical = list(df.select_dtypes(include=['object']).columns)
numerical = list(df.select_dtypes(include=['number']).columns)

# %%
numerical.remove('churn')

# %%
df[categorical].nunique()
# Out:
# gender              2
# seniorcitizen       2
# partner             2
# dependents          2
# phoneservice        2
# multiplelines       3
# internetservice     3
# onlinesecurity      3
# onlinebackup        3
# deviceprotection    3
# techsupport         3
# streamingtv         3
# streamingmovies     3
# contract            3
# paperlessbilling    2
# paymentmethod       4
# dtype: int64

# %%
global_mean = df.churn.mean()
global_mean
# Out:
# np.float64(0.2653698707936959)

# %%
from IPython.display import display

# %%
for feature in categorical:
    df_group = df.groupby(by=feature).churn.agg(['mean'])
    df_group['diff'] = df_group['mean'] - global_mean
    df_group['risk'] = df_group['mean'] / global_mean
    display(df_group)
# Out:
#             mean      diff      risk
# gender
# Female  0.269209  0.003839  1.014466
# Male    0.261603 -0.003766  0.985807
#                    mean      diff      risk
# seniorcitizen
# 0              0.236062 -0.029308  0.889557
# 1              0.416813  0.151443  1.570686
#              mean      diff      risk
# partner
# No       0.329580  0.064210  1.241964
# Yes      0.196649 -0.068721  0.741038
#                 mean      diff      risk
# dependents
# No          0.312791  0.047422  1.178700
# Yes         0.154502 -0.110868  0.582215
#                   mean      diff      risk
# phoneservice
# No            0.249267 -0.016103  0.939319
# Yes           0.267096  0.001726  1.006506
#                       mean      diff      risk
# multiplelines
# No                0.250442 -0.014927  0.943749
# No phone service  0.249267 -0.016103  0.939319
# Yes               0.286099  0.020729  1.078114
#                      mean      diff      risk
# internetservice
# ...

# %%
#seniorcitizen - dependents - internetservice - onlinesecurity - onlinebackup - deviceprotection - techsupport - contract - paymentmethod ??
from sklearn.metrics import mutual_info_score
def calculate_mi(series):
    return mutual_info_score(series,df.churn)

df_mi = df[categorical].apply(calculate_mi)
df_mi = df_mi.sort_values(ascending = False).to_frame(name = 'MI')
display(df_mi.head())
display(df_mi.tail())
# Out:
#                        MI
# contract         0.098453
# onlinesecurity   0.064677
# techsupport      0.063021
# internetservice  0.055574
# onlinebackup     0.046792
#                      MI
# partner        0.011454
# seniorcitizen  0.010577
# multiplelines  0.000801
# phoneservice   0.000072
# gender         0.000037

# %%
df[numerical].corrwith(df.churn)
# Out:
# tenure           -0.352229
# monthlycharges    0.193356
# totalcharges     -0.199037
# dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
df_full_train, df_test = train_test_split(df,test_size=0.2, random_state=1)
df_train, df_valid = train_test_split(df_full_train, test_size=0.2, random_state=1)
print("Training Data Size: ", df_train.shape)
print("Validation Data Size: ", df_valid.shape)
print("Testing Data Size: ", df_test.shape)
# Out:
# Training Data Size:  (4507, 20)
# Validation Data Size:  (1127, 20)
# Testing Data Size:  (1409, 20)

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import StandardScaler

# %%
df_test.head()
# Out:
#       gender seniorcitizen partner dependents  tenure phoneservice  \
# 3381  Female             0      No         No      41          Yes
# 6180  Female             1      No         No      66          Yes
# 4829  Female             0      No         No      12          Yes
# 3737  Female             0      No         No       5          Yes
# 4249  Female             0     Yes        Yes      10          Yes
#
#      multiplelines internetservice onlinesecurity onlinebackup  \
# 3381            No             DSL            Yes           No
# 6180           Yes     Fiber optic            Yes           No
# 4829            No             DSL             No           No
# 3737           Yes             DSL             No           No
# 4249            No             DSL             No          Yes
#
#      deviceprotection techsupport streamingtv streamingmovies        contract  \
# 3381              Yes         Yes         Yes             Yes        One year
# ...

# %%
def preprocess(df_train, df_valid, df_test, cat, num):
    OHE = OneHotEncoder(drop='first')
    scaler = StandardScaler()
    transformer = make_column_transformer((OHE,cat), (scaler, num), remainder='passthrough', verbose_feature_names_out=False)

    X_train = transformer.fit_transform(df_train[cat+num])
    X_valid = transformer.transform(df_valid[cat+num])
    X_test = transformer.transform(df_test[cat+num])
    columns=transformer.get_feature_names_out()

    return X_train , X_valid, X_test, columns

# %%
X_train , X_valid, X_test, columns = preprocess(df_train, df_valid, df_test, categorical, numerical)

# %%
y_train = df_train['churn']
y_valid = df_valid['churn']
y_test = df_test['churn']

# %%
from sklearn.linear_model import LogisticRegression
model_1 = LogisticRegression(solver='liblinear', random_state=1)
model_1.fit(X_train,y_train)
# Out:
# LogisticRegression(random_state=1, solver='liblinear')

# %%
len(columns)
# Out:
# 30

# %%
y_val_pred = model_1.predict_proba(X_valid)
y_val_pred
# Out:
# array([[0.99288506, 0.00711494],
#        [0.79974135, 0.20025865],
#        [0.78818009, 0.21181991],
#        ...,
#        [0.96095723, 0.03904277],
#        [0.41986996, 0.58013004],
#        [0.70082799, 0.29917201]], shape=(1127, 2))

# %%
y_test_pred = model_1.predict_proba(X_test)
y_test_pred
# Out:
# array([[0.94320787, 0.05679213],
#        [0.91336162, 0.08663838],
#        [0.66581461, 0.33418539],
#        ...,
#        [0.99473367, 0.00526633],
#        [0.8057315 , 0.1942685 ],
#        [0.39371364, 0.60628636]], shape=(1409, 2))

# %%
y_test_pred = (y_test_pred[:,1] > 0.6).astype(int)

# %%
(y_test_pred == y_test).mean()
# Out:
# np.float64(0.815471965933286)

# %%
print('LogisticRegression Training Accuracy: ', round(model_1.score(X_train, y_train), 2))
print('LogisticRegression Validation Accuracy: ', round(model_1.score(X_valid, y_valid), 2))
print('LogisticRegression Testing Accuracy: ', round(model_1.score(X_test, y_test), 2))
# Out:
# LogisticRegression Training Accuracy:  0.8
# LogisticRegression Validation Accuracy:  0.8
# LogisticRegression Testing Accuracy:  0.81

# %%
#repeat training for most important categorical features

# %%
df_mi
# Out:
#                         MI
# contract          0.098453
# onlinesecurity    0.064677
# techsupport       0.063021
# internetservice   0.055574
# onlinebackup      0.046792
# paymentmethod     0.044519
# deviceprotection  0.043917
# streamingmovies   0.032001
# streamingtv       0.031908
# paperlessbilling  0.019194
# dependents        0.014467
# partner           0.011454
# seniorcitizen     0.010577
# multiplelines     0.000801
# phoneservice      0.000072
# gender            0.000037

# %%
# take first 5 
imp5 = df_mi.head().index.to_list()

# %%
X_train , X_valid, X_test, columns = preprocess(df_train, df_valid, df_test, imp5, numerical)
model_2 = LogisticRegression(solver='liblinear', random_state=1)
model_2.fit(X_train,y_train)
# Out:
# LogisticRegression(random_state=1, solver='liblinear')

# %%
print('LogisticRegression Training Accuracy: ', round(model_2.score(X_train, y_train), 2))
print('LogisticRegression Validation Accuracy: ', round(model_2.score(X_valid, y_valid), 2))
print('LogisticRegression Testing Accuracy: ', round(model_2.score(X_test, y_test), 2))
# Out:
# LogisticRegression Training Accuracy:  0.79
# LogisticRegression Validation Accuracy:  0.8
# LogisticRegression Testing Accuracy:  0.8

# %%
# take first 9 
imp9 = df_mi.head(9).index.to_list()

# %%
X_train , X_valid, X_test, columns = preprocess(df_train, df_valid, df_test, imp9, numerical)
model_3 = LogisticRegression(solver='liblinear', random_state=1)
model_3.fit(X_train,y_train)
# Out:
# LogisticRegression(random_state=1, solver='liblinear')

# %%
print('LogisticRegression Training Accuracy: ', round(model_3.score(X_train, y_train), 2))
print('LogisticRegression Validation Accuracy: ', round(model_3.score(X_valid, y_valid), 2))
print('LogisticRegression Testing Accuracy: ', round(model_3.score(X_test, y_test), 2))
# Out:
# LogisticRegression Training Accuracy:  0.8
# LogisticRegression Validation Accuracy:  0.8
# LogisticRegression Testing Accuracy:  0.8

# %%
#no difference between considering all categorical features and considering only the most important 5 or 9

# %%
#try numerical features only
X_train = df_train[numerical]
X_valid = df_valid[numerical]
X_test  = df_test[numerical]

model_4 = LogisticRegression(solver='liblinear', random_state=1)
model_4.fit(X_train, y_train)
print('LogisticRegression Training Accuracy: ', round(model_4.score(X_train, y_train), 2))
print('LogisticRegression Validation Accuracy: ', round(model_4.score(X_valid, y_valid), 2))
print('LogisticRegression Testing Accuracy: ', round(model_4.score(X_test, y_test), 2))
# Out:
# LogisticRegression Training Accuracy:  0.78
# LogisticRegression Validation Accuracy:  0.79
# LogisticRegression Testing Accuracy:  0.8

# %%
# If accuracy is acceptable, use model_2 or model_4 depending on future data availability — skip features that are unnecessary and hard to collect later.

# %%
import pickle 

pickle.dump(model_2, open("log_reg.pkl", 'wb'))

# %%
loaded_model = pickle.load(open('log_reg.pkl', 'rb'))

# %%
#using the model for random cutomers in testing dataset
X_train , X_valid, X_test, columns = preprocess(df_train, df_valid, df_test, imp5, numerical)
result = loaded_model.predict(X_test[5:10])
result
# Out:
# array([0, 0, 1, 0, 0])
